# %% [markdown]
# <a href="https://colab.research.google.com/github/ksm1560/cmcoding/blob/master/%EC%B6%A9%EB%82%A8%EC%BD%98%EB%9E%A9_GPT%EC%BD%94%EB%94%A9_%EC%98%88%EC%A0%9C%EC%BD%94%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #로또번호 생성기 만들기
# - chatGPT에서 로또번호 생성기를 만들어달라고 요청해 봅시다.

# %% [markdown]
# #QR코드 생성기 만들기
# - chatGPT에서 QR코드 생성기를 만들어달라고 요청해 봅시다.

# %% [markdown]
# #오토마우스 카카오톡 자동화 프로그램
#  - GPT에게 요청하면
#     - 죄송합니다만, 카카오톡 등의 메신저 서비스에는 자동화를 통한 메시지 전송이나 기타 활동이 약관에 위배될 수 있습니다. 이러한 행동은 서비스 제공자의 이용 약관을 준수하는 것이 중요하며, 무단으로 자동화 프로그램을 사용하는 것은 피해야 합니다.
#
#  - 이미 만들어져있는 소스 수정해서 사용하기
#  - 캡쳐 이미지 필요 3장
#
#  ![pic3.png](data:image/png;base64,...)![pic2.png](data:image/png;base64,...)![pic1.png](data:image/png;base64,...)

# %%
import pyautogui
import pyperclip
import datetime
import threading
import time
import os

# 경로를 .py 파일의 실행 경로로 이동
os.chdir(os.path.dirname(os.path.abspath(__file__)))

# 원하는 시간 설정 (오후 6시 25분)
desired_hour = 18
desired_minute = 27

def send_message():
    threading.Timer(60, send_message).start()  # 매 분마다 확인

    now = datetime.datetime.now()
    if now.hour == desired_hour and now.minute == desired_minute:
        pic_position = pyautogui.locateOnScreen('pic1.png')
        print(pic_position)

        if pic_position is None:
            pic_position = pyautogui.locateOnScreen('pic2.png')
            print(pic_position)

        if pic_position is None:
            pic_position = pyautogui.locateOnScreen('pic3.png')
            print(pic_position)

        click_position = pyautogui.center(pic_position)
        pyautogui.doubleClick(click_position)

        pyperclip.copy("이 메세지는 자동으로 보내는 메세지입니다~~")
        pyautogui.hotkey("ctrl", "v")
        time.sleep(1.0)

        pyautogui.write(["enter"])
        time.sleep(1.0)

        pyautogui.write(["escape"])
        time.sleep(1.0)

# 초기에 한번 실행
send_message()

# %% [markdown]
# #지렁이 게임 만들기
#  - GPT에게 요청.
#  - colab환경에서 실행 어려움
#  - visual studio code 활용하기

# %% [markdown]
# #판다스 시각화
#  - GPT에게 요청
